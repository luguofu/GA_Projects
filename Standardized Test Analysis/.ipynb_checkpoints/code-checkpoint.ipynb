# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Given that in 2016, the SATs and ACTs underwent a revamp. we want to study the participation rate for both tests from the southern region (Alabama, Arkansas, Delaware, Florida, Georgia, Kentucky, Louisiana, Maryland, Mississippi, North Carolina, Oklahoma, South Carolina, Tennesse, Texas, Virginia, West Virginia, District of Columbia) of the United States from then till 2019. We seek to identify trends in the data and to identify a state to be best recommended for College Board fund investment to boost SAT participation rates.and to provide recommendations for increasing of participation rate if necessary
#
# The analysis will be split into the four relevant regions in the USA (Northeast, Midwest, South & West) and conclude with an overall recommended state.
#
#
# * I will only be covering the South Region while the rest of the regions are covered by the rest of the individuals in the group project. we will be combining the data and anaylsis for our presentation.

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# This project aims to analyze the data for student participation rates and scores by states in the southern region(combined states observations and recommendations to be presented in the group presentation). The data are organized into state level containing 2017, 2018, 2019 SAT/ACT participation rates, total and composite scores. This allows us to conduct a state by state comparison of data and observations.
#
# A strong negative correlation is observed between ACT and SAT participation whereby states with more ACT participation, there would be low SAT participation as expected. the other strong negative correlation is between the participation rate and scores of both SAT and ACT exams. it is observed that increased participation would result in lower average scores. this is evident of selection bias. Hence, comparison of average scores among states with large participation rate should be avoided.
#
# Participation rates in the South are healthy with no states falling below 50% participation in both ACT and SAT. It is also noteable that full participation of ACT/ SAT tests are driven by state policy requirements.
#
# For 2019, Virginia is the least performing state participation for SAT and ACT participation rates combined. Thus, we will be recommending Virginia from the southern region for College Board fund investment.
#
# SAT school day is evidently able to encourage increase participation rate evidently from Florida's data. states with low participation rate should adopt such programmes to increase participation rate.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %%
#description of datasets to be used
import pandas as pd

data = [('act_2017.csv', 'This dataset includes Participation rate in %, avg scores for English, Math, Reading, Science and Composite by state'),
       ('act_2018.csv', 'This dataset includes Participation rate in % and avg Composite Scores by state'),
       ('act_2019.csv', 'This dataset includes Participation rate in % and avg Composite Scores by state'),
       ('sat_2017.csv', 'This dataset includes Participation rate in % , avg scores of participants for Evidence based reading and writing, Math and Total avg scores by state'),
       ('sat_2018.csv', 'This dataset includes Participation rate in % , avg scores of participants for Evidence based reading and writing, Math and Total avg scores by state'),
       ('sat_2019.csv', 'This dataset includes Participation rate in % , avg scores of participants for EBRW, Math and Total avg scores by state'),]

columns = ['Dataset file', 'Description']

df = pd.DataFrame(data, columns = columns)
pd.set_option('display.max_colwidth', None)
df
# Out:
#    Dataset file  \
# 0  act_2017.csv
# 1  act_2018.csv
# 2  act_2019.csv
# 3  sat_2017.csv
# 4  sat_2018.csv
# 5  sat_2019.csv
#
#                                                                                                                                              Description
# 0                                   This dataset includes Participation rate in %, avg scores for English, Math, Reading, Science and Composite by state
# 1                                                                        This dataset includes Participation rate in % and avg Composite Scores by state
# 2                                                                        This dataset includes Participation rate in % and avg Composite Scores by state
# 3  This dataset includes Participation rate in % , avg scores of participants for Evidence based reading and writing, Math and Total avg scores by state
# ...

# %% [markdown]
# We will be selecting the data for act_2017, act_2018, act_2019, sat_2017, sat_2018, act_2019 for our analysis related to our problem statement of identifying the trend of participation rate from 2017 to 2019.

# %% [markdown]
# Data provided are state by state breakdown of ACT and SAT scores for the year 2017, 2018, 2019. The values in the cells are averages. whilst the participation rates are in percentages
#
# ACT data:
# 1. act_2017 has 6 columns of data which includes participation rate in %, avg scores for English, Math, Reading, Science and Composite data by state.
# 2. act_2018 and 2019 has 3 columns of data which includes the participation rate in % and composite scores
# 3. Composite data is calculated by the the average of English, Math, Reading, Science scores
# 4. Participation rate relates to the rate of high school students taking the ACT exams.
# 5. ACT scores ranges from 1 to 36
#
# SAT data:
# 1. The sat_2017, 2018, 2019 data has 3 columns of data which includes the Evidence based reading and writing, Math and total avg scores
# 2. the SAT subjects have a score range from 200 to 800
# 3. the Total score have a range of 400 to 1600
# 4. the Total score is attained by summing the Evidence based reading and writing and math subjects

# %% [markdown]
# ### Outside Research

# %% [markdown]
# The following are the summary of the state required test for the southern states from 2017 to 2019:
#
# | S/N |      State     |       High School Test 16-17       |                                       Remarks                                       |                                 High School Test 18-19                                |
# |:---:|:--------------:|:----------------------------------:|:-----------------------------------------------------------------------------------:|:-------------------------------------------------------------------------------------:|
# |  1  |     Alabama    | ACT Aspire, ACT,  Workkeys         |                                                                                     |                                                                                       |
# |  2  |    Arkansas    | ACT Aspire                         | School must offer ACT, Students not required to participate                         |                                                                                       |
# |  3  |     Delware    | PSAT, SAT                          |                                                                                     |  SAT                 |
# |  4  |     Florida    | FSA                                | Students must pass  end of course tests                                             |                                                                                       |
# |  5  |     Georgia    | Georgia  Milestones                |                                                                                     |                                                                                       |
# |  6  |    Kentucky    | K-Prep, ACT, QualityCore           |                                                                                     |                                                                                       |
# |  7  |    Louisiana   | End of Course Tests, ACT           | Students must pass end of course tests                                              | Students may substitute Workkeys for ACT                                              |
# |  8  |    Maryland    | MCAS                               | Students must pass  MCAS                                                            |                                                                                       |
# |  9  |   Mississippi  | MAP, ACT                           | must pass MAP or  substitute ACT  scores                                            |                                                                                       |
# |  10 | North Carolina | SBAC, ACT/workkeys                 | Students must take  ACT or WorkKeys.  scores does not  affect grades or  graduation | End of Course Tests, ACT. WorkKeys for students completing career Technical Education |
# |  11 |    Oklahoma    | OSTP                               |                                                                                     | ACT or SAT                                                                            |
# |  12 | South Carolina | End of course tests, ACT, WorkKeys |                                                                                     | End of course tests                                                                   |
# |  13 |    Tennessee   | End of course tests,  ACT/SAT      | Students must take  ACT or SAT                                                      | District chooses between ACT or SAT                                                   |
# |  14 |      Texas     | STAAR                              | Students must pass end of course tests                                              |                                                                                       |
# |  15 |     Virgina    | SOL                                | Students must pass  end ofcourse test  or ACT/SAT                                   |                                                                                       |
# |  16 |  West Virginia | SBAC                               |                                                                                     | SAT                                                                                   |

# %% [markdown]
# we can see from our external research gathered from edweek.org, that most of the states favour ACT over SATs.but in 2019, states are increasingly starting to shift towards to SAT testing as part of their graduation citeria. whilst there are still a number of states still requires their students to take their school administered end of courses while leaving the ACT/SAT as an option to supplement the students' citeria to graduate. we also can see that there was a significant shift for Delaware (source: whhy.org) and West virginia to adopt SAT as their state test.
#
# the colleage school board has also implemented SAT school day to increase easier access to convinence and comfort, whereby SAT supportive states offers students to take the SAT test in the schools instead of trying to look for a testing center to participate in the test and the comfort of familiar surroundings and students taking the test. they also offered confindence practice testing whereby free, personalized practice plans for all students. 'Official SAT Practice on Khan Academy® provides every student with a practice plan built just for them, along with integrated coaching tools for teachers to view progress and support their students'.(quoted from https://collegereadiness.collegeboard.org/sat/k12-educators/sat-school-day/about#:~:text=SAT%20School%20Day%20provides%20schools,accepted%20at%20all%20U.S.%20colleges.).
#
# Florida has also seen a significant shift to SAT test taking attributed to the SAT school day programme. it is worth studying the usefullness of this programe to drive up voluntary participation rates.
#
# with these observations. SAT participation rates may still be increasingly popular as times goes by until the ACT board steps up its effort to entice students to take the ACT test to increase participation.

# %% [markdown]
# sources:
#
# * state requirements 16-17: https://www.edweek.org/leadership/what-tests-did-each-state-require-in-2016-17
# * state requirements 18-19: https://www.edweek.org/teaching-learning/what-tests-does-each-state-require
# * delware shift to SAT: https://whyy.org/articles/sat-to-the-rescue-why-delaware-and-other-states-are-embracing-a-new-role-for-an-old-test/
# * which states requires the SAT or ACT: https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice
# * florida shifts to SAT: https://www.orlandosentinel.com/news/education/os-ne-sat-scores-florida-20190924-2ycpuogc2ndkrkwzdrkrjgrg64-story.html
# * SAT school day: https://collegereadiness.collegeboard.org/sat/k12-educators/sat-school-day/about

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def calc_mean(list_numbers): # define the function
    return sum(list_numbers)/len(list_numbers) # set the condition sum of the list / no. of variable in list and return

# %%
lst_numbers = [1,2,3,4,5,6,7,8] #create the list of variables
calc_mean(lst_numbers) #call the function with the list
# Out:
# 4.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def calc_stdev(list_numbers): # define the function
    sum_sqr = 0 #variable = 0 to be added with value on condition
    avg = sum(list_numbers)/len(list_numbers) # mean of the list
    for x in list_numbers: # create a for loop runing through the list of variables
        parenthesis = (x - avg)**2 # for x in list, - average and sq
        sum_sqr = sum_sqr + parenthesis # add the value to the sum_sqr variable 
    before_square_root = (sum_sqr) * (1/len(list_numbers)) #sum_sq * 1/n(number of variables in list)
    std = before_square_root**0.5 #square root of the equation
    
    return std

# %%
calc_stdev(lst_numbers) # call the funtion with the intended variable list
# Out:
# 2.29128784747792

# %% [markdown]
# ## 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc.

# %%
def sc2f(x): # define function sc2f(x)
    return float(x.strip('%'))/100 # strip '%' from value and then / 100 then convert to dtype to float

# %%
sc2f("50%") #call the function of an example of value in %
# Out:
# 0.5

# %% [markdown]
# ---
# # Part 2
#
# Part 2: Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:

# %% [markdown]
# ### 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

# %%
# import dataframes needed:
act_17 = pd.read_csv('../data/act_2017.csv')
act_18 = pd.read_csv('../data/act_2018.csv')
act_19 = pd.read_csv('../data/act_2019.csv')

sat_17 = pd.read_csv('../data/sat_2017.csv')
sat_18 = pd.read_csv('../data/sat_2018.csv')
sat_19 = pd.read_csv('../data/sat_2019.csv')

# %%
#print 1st 5 rows of act dataframes
act_17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_18.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act_19.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
sat_17.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_19.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %% [markdown]
# ### 2. Check for missing values.

# %%
#check any missing values in each dataframe
print(act_17.isnull().sum())
print(act_18.isnull().sum())
print(act_19.isnull().sum())

print(sat_17.isnull().sum())
print(sat_18.isnull().sum())
print(sat_19.isnull().sum())
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64
# State            0
# Participation    0
# Composite        0
# dtype: int64
# State            0
# Participation    0
# Composite        0
# dtype: int64
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %% [markdown]
# * There are no missing values in the dataframes

# %% [markdown]
# ### 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %% [markdown]
# #### ACT Scores
# - the possible min and max score for ACT is 1 and 36 respectively

# %%
act_17.describe() #describe and investigate the data output
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# * Dataframe not displaying Composite column. this may be due to the column dtype

# %%
#find the error in the act_17.composite column not numeric
act_17[pd.to_numeric(act_17['Composite'], errors = 'coerce').isnull()] 
#the value in row 51 is an error displaying 20.2x minx of string and numeric value where this is not ideal in our analysis
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
act_17.dtypes #check the data type of the composite column
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# * The value in row 51, Composite column is displaying 20.2x. this should be 20.2 instead. might be a typo error. datatype for the composite column is object. we will want this data type to be float

# %%
# act_17 minimum science score displaying 2.3 . to investigate

act_17[act_17['Science'] == 2.3]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %%
# check somposite score for Maryland
mary_comp = act_17.loc[21][['English', 'Math', 'Reading', 'Science']].sum() / 4 # sum subject columns and average the total
mary_comp
# Out:
# 18.225

# %% [markdown]
# * The comoposite score for Maryland should be 18.225 instead of 23.6

# %%
act_18.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
act_19.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %% [markdown]
# * The count for all act dataframes is 52. there is only 50 states in the united states with index being 0, the total count should be 51. we shall investigate the state column with sat_18 state column. we have verified that sat_18 state column values is accurate

# %%
#compare act_17.state to sat_18.state and loc the different row
act_17.loc[~act_17['State'].isin(sat_18['State'])]
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0

# %% [markdown]
# * National is not a state in the US. we will drop this row

# %%
#compare act_18.state to sat_18.state and loc the different row
act_18.loc[~act_18['State'].isin(sat_18['State'])]
# Out:
#                   State Participation  Composite
# 8  District of columbia           32%       23.6

# %%
sat_18.loc[~sat_18['State'].isin(act_18['State'])]
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 8  District of Columbia           92%                                 497
#
#    Math  Total
# 8   480    977

# %% [markdown]
# * The difference for the state column act_18 and sat_18 is the upper and lower case of the District of Columbia. we will correct the upper case and lower case string to be consistent with the other data frames. whilst the count value of act_18 is still 52, we will check if there is any duplicate in this column.

# %%
act_18.duplicated().sum() #check for any duplicate rows in act_18 since there are no other difference in rows
# Out:
# 1

# %%
act_18[act_18.duplicated(keep = False)] #identify the duplicate rows
# Out:
#     State Participation  Composite
# 19  Maine            7%       24.0
# 20  Maine            7%       24.0

# %% [markdown]
# * We have found the duplicate row of Maine and will drop one of the duplicated row

# %%
#compare act_19.state to sat_18.state and loc the different row
act_19.loc[~act_19['State'].isin(sat_18['State'])]
# Out:
#        State Participation  Composite
# 51  National           52%       20.7

# %% [markdown]
# * National is not a state in the US. we will drop this row

# %% [markdown]
# #### SAT Scores
# - the possible min score for SAT scores for subjects (EBRW and Math) is 200 and composite is 400.
# - the possible max score for SAT scores for subjects is 800 and composite is 1600.

# %%
sat_17.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# * Min score for Math, 52.0 is below 200. this is inaccurate

# %%
sat_18.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
sat_19.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %% [markdown]
# * sat_19 for the count of 53. this should be 51

# %%
#compare the sat_19 state list with sat_18(verified) and return the different value 
sat_19.loc[~sat_19['State'].isin(sat_18['State'])]
# Out:
#              State Participation Rate  EBRW  Math  Total
# 39     Puerto Rico                  —   483   462    944
# 47  Virgin Islands                  —   490   445    935

# %% [markdown]
# *  Puerto Rico and Virgin Islands are not states of the US. we will remove these rows

# %% [markdown]
# ## 4. Fix errors identified in steps 2-3.

# %% [markdown]
# * Fix error for act_17.Composite data type and replace strg

# %%
#convert datatype of column to float and if any non-numeric value to NaN
act_17['Composite'] = pd.to_numeric(act_17['Composite'], errors = 'coerce') 
act_17[act_17['Composite'].isnull()]   #display the NaN in column row
# Out:
#       State Participation  English  Math  Reading  Science  Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6        NaN

# %%
# Calculate the Composite score by adding all the subject scores and / no. of subjects
sum_comp_score = act_17.iloc[51, [2,3,4,5]].sum()/4 # sum the value of wyoming subject values and divde by 4
comp_score = round(sum_comp_score,1) #round the value 
comp_score
# Out:
# 20.2

# %%
#replace the Nan value in the composite column to comp_score the expected value, assuming the the string x is a typo
act_17['Composite'] = act_17['Composite'].replace(np.nan, comp_score, regex=True)

# %%
act_17.loc[51:] #check replaced value using loc row number 51
# Out:
#       State Participation  English  Math  Reading  Science  Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6       20.2

# %% [markdown]
# *  Fix error of act_17 Maryland composite score

# %%
mary_comp = act_17.loc[21][['English', 'Math', 'Reading', 'Science']].sum() / 4 # sum subject columns and average the total
mary_comp = round(mary_comp,2) 
# actual composite score of Maryland
mary_comp
# Out:
# 18.23

# %%
act_17['Composite'].replace([23.6], mary_comp, inplace = True) #replace value with actual value of composite score
act_17[act_17['State']=='Maryland']
# Out:
#        State Participation  English  Math  Reading  Science  Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3     18.225

# %% [markdown]
# * Drop rows for the state, National in act_17 and act_19

# %%
act_17[act_17['State'] == 'National'] #identify the National state row in act_17
# Out:
#       State Participation  English  Math  Reading  Science  Composite
# 0  National           60%     20.3  20.7     21.4     21.0       21.0

# %%
act_19[act_19['State'] == 'National'] #identify the Nationial state row in act_19
# Out:
#        State Participation  Composite
# 51  National           52%       20.7

# %%
#Get indexes where state column has value National
todrop17 = act_17[act_17['State'] == 'National'].index
todrop19 = act_19[act_19['State'] == 'National'].index

#Drop the row indexes from dataframe
act_17.drop(todrop17, inplace = True)
act_19.drop(todrop19, inplace = True)

# %%
act_17.reset_index(drop = True, inplace = True) # reset the index
act_17.head(3) #check
# Out:
#      State Participation  English  Math  Reading  Science  Composite
# 0  Alabama          100%     18.9  18.4     19.7     19.4       19.2
# 1   Alaska           65%     18.7  19.8     20.4     19.9       19.8
# 2  Arizona           62%     18.6  19.8     20.1     19.8       19.7

# %%
act_19.tail(3) #national value was in row 51, hence using tail to check and need not to reset the index
# Out:
#             State Participation  Composite
# 48  West Virginia           49%       20.8
# 49      Wisconsin          100%       20.3
# 50        Wyoming          100%       19.8

# %% [markdown]
# * Correct the lower and upper case for the value of 'District of columbia' to 'District of Columbia' in act_18.state column

# %%
#replace the 'District of columbia' to 'District of Columbia' in the act_18.State column
act_18['State'] = act_18['State'].str.replace('District of columbia', 'District of Columbia')

# %%
act_18[act_18.State == 'District of Columbia'] #check value
# Out:
#                   State Participation  Composite
# 8  District of Columbia           32%       23.6

# %% [markdown]
# * Drop duplicate row in act_18

# %%
act_18.drop_duplicates(inplace=True) #drop duplicate row
act_18.duplicated().sum() #check any duplicated rows
# Out:
# 0

# %%
act_18.reset_index(drop = True, inplace = True) #resets the index and drop the previous index

# %%
act_18.loc[7:10] #check
# Out:
#                    State Participation  Composite
# 7               Delaware           17%       23.8
# 8   District of Columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4

# %% [markdown]
# * Fix error for sat_2017 where sat score of 52 is below min value possible for sat score

# %%
# filter and identified the math column which score is <200 which less than the min score of Sats subject
sat_17[sat_17['Math']<200]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
# calculate the value of the error math column
math_score = sat_17.loc[20]['Total'] - sat_17.loc[20]['Evidence-Based Reading and Writing']
#replace the error of 52 to 524
sat_17['Math'].replace({52: math_score }, inplace = True ) 
#check replaced?
sat_17.loc[20:20]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %% [markdown]
# * Drop the states, Puerto Rico and Virgin Islands in sat_19 as they are not states in the US

# %%
# identify the states that are not the states of america by comparing with sat_19
sat_19.loc[~sat_19['State'].isin(sat_18['State'])]
# Out:
#              State Participation Rate  EBRW  Math  Total
# 39     Puerto Rico                  —   483   462    944
# 47  Virgin Islands                  —   490   445    935

# %%
#drop the rows 39, 47 as we will not need them for our analysis
sat_19.drop([39,47], axis = 0, inplace = True)

# %%
#reset the index and drop previous index
sat_19.reset_index(drop = True, inplace = True)

# %%
sat_19.iloc[38:48] #check
# Out:
#              State  Participation Rate  EBRW  Math  Total
# 38    Pennsylvania                0.70   545   537   1082
# 39    Rhode Island                1.00   503   492    995
# 40  South Carolina                0.68   526   504   1030
# 41    South Dakota                0.03   633   635   1268
# 42       Tennessee                0.07   618   602   1220
# 43           Texas                0.68   515   507   1022
# 44            Utah                0.04   614   615   1230
# 45         Vermont                0.66   560   546   1106
# 46        Virginia                0.68   567   551   1119
# 47      Washington                0.70   539   535   1074

# %% [markdown]
# ## 5. Display the data types of each feature.

# %%
act_17.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
act_18.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act_19.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
sat_17.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_18.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_19.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %% [markdown]
# * All the participation rate for the listed dataframes data types are object, we will want to convert them into float as this will help in the anaylsis of this project using numeric values

# %% [markdown]
# ## 6. Fix incorrect data types found in step 5.
#     - Fix values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats!

# %% [markdown]
# * Strip the % from the participation column and convert to float for all data frames

# %%
def sc2f(percent_to_flt): # define function
    return float(percent_to_flt.strip('%'))/100 #takes string type %, strip the % and convert to float then divide by 100 to represent value

#converts the particpation column into float value
act_17['Participation'] = act_17['Participation'].map(lambda x: sc2f(x))
act_18['Participation'] = act_18['Participation'].map(lambda x: sc2f(x))
act_19['Participation'] = act_19['Participation'].map(lambda x: sc2f(x))
sat_17['Participation'] = sat_17['Participation'].map(lambda x: sc2f(x))
sat_18['Participation'] = sat_18['Participation'].map(lambda x: sc2f(x))
sat_19['Participation Rate'] = sat_19['Participation Rate'].map(lambda x: sc2f(x))

# %%
#check all dataframe if converted
act_17.head(3)
# Out:
#      State  Participation  English  Math  Reading  Science  Composite
# 0  Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 1   Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 2  Arizona           0.62     18.6  19.8     20.1     19.8       19.7

# %%
act_17.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
act_18.head(3)
# Out:
#      State  Participation  Composite
# 0  Alabama           1.00       19.1
# 1   Alaska           0.33       20.8
# 2  Arizona           0.66       19.2

# %%
act_18.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
act_19.head(3)
# Out:
#      State  Participation  Composite
# 0  Alabama           1.00       18.9
# 1   Alaska           0.38       20.1
# 2  Arizona           0.73       19.0

# %%
act_19.dtypes
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
sat_17.head(3)
# Out:
#      State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama           0.05                                 593   572   1165
# 1   Alaska           0.38                                 547   533   1080
# 2  Arizona           0.30                                 563   553   1116

# %%
sat_17.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
sat_18.head(3)
# Out:
#      State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama           0.06                                 595   571   1166
# 1   Alaska           0.43                                 562   544   1106
# 2  Arizona           0.29                                 577   572   1149

# %%
sat_18.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
sat_19.head(3)
# Out:
#      State  Participation Rate  EBRW  Math  Total
# 0  Alabama                0.07   583   560   1143
# 1   Alaska                0.41   556   541   1097
# 2  Arizona                0.31   569   565   1134

# %%
sat_19.dtypes
# Out:
# State                  object
# Participation Rate    float64
# EBRW                    int64
# Math                    int64
# Total                   int64
# dtype: object

# %% [markdown]
# ### 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.

# %%
act_17.rename(columns ={"State": "state", "Participation":"participation_act_17", "English":"english_act_17", 
                        "Math": "math_act_17", "Reading": "reading_act_17", "Science": "science_act_17",
                       "Composite": "composite_act_17"}, inplace = True)
act_17.columns #check
# Out:
# Index(['state', 'participation_act_17', 'english_act_17', 'math_act_17',
#        'reading_act_17', 'science_act_17', 'composite_act_17'],
#       dtype='object')

# %%
act_18.rename(columns = {"State": "state", "Participation": "participation_act_18", "Composite": "composite_act_18"},
             inplace = True)
act_18.columns
# Out:
# Index(['state', 'participation_act_18', 'composite_act_18'], dtype='object')

# %%
act_19.rename(columns = {"State": "state", "Participation": "participation_act_19", "Composite": "composite_act_19"},
             inplace = True)
act_19.columns
# Out:
# Index(['state', 'participation_act_19', 'composite_act_19'], dtype='object')

# %%
sat_17.rename(columns={ "State": "state", "Participation": "participation_sat_17", "Evidence-Based Reading and Writing" : "ebrw_sat_17",
                      "Math": "math_sat_17", "Total": "total_sat_17"}, inplace = True) #rename columns
sat_17.columns #check
# Out:
# Index(['state', 'participation_sat_17', 'ebrw_sat_17', 'math_sat_17',
#        'total_sat_17'],
#       dtype='object')

# %%
sat_18.rename(columns={ "State": "state", "Participation": "participation_sat_18", "Evidence-Based Reading and Writing" : "ebrw_sat_18",
                      "Math": "math_sat_18", "Total": "total_sat_18"}, inplace = True) #rename columns
sat_18.columns #check
# Out:
# Index(['state', 'participation_sat_18', 'ebrw_sat_18', 'math_sat_18',
#        'total_sat_18'],
#       dtype='object')

# %%
sat_19.rename(columns={ "State": "state", "Participation Rate": "participation_sat_19", "EBRW" : "ebrw_sat_19",
                      "Math": "math_sat_19", "Total": "total_sat_19"}, inplace = True) #rename columns
sat_19.columns #check
# Out:
# Index(['state', 'participation_sat_19', 'ebrw_sat_19', 'math_sat_19',
#        'total_sat_19'],
#       dtype='object')

# %% [markdown]
# ## 8. Drop unnecessary rows (if needed).

# %% [markdown]
# nil

# %% [markdown]
# ## 9. Merge dataframes that can be merged.

# %%
# merging ACT participation rate and scores
act_1718 = act_17.merge(act_18, how = 'left', on = 'state') #merge act_18 to act_17 on 'state'
merged_act = act_1718.merge(act_19, how = 'left', on ='state') # merge act_19 to act_1718 on 'state'
merged_act.head(3)
# Out:
#      state  participation_act_17  english_act_17  math_act_17  reading_act_17  \
# 0  Alabama                  1.00            18.9         18.4            19.7
# 1   Alaska                  0.65            18.7         19.8            20.4
# 2  Arizona                  0.62            18.6         19.8            20.1
#
#    science_act_17  composite_act_17  participation_act_18  composite_act_18  \
# 0            19.4              19.2                  1.00              19.1
# 1            19.9              19.8                  0.33              20.8
# 2            19.8              19.7                  0.66              19.2
#
#    participation_act_19  composite_act_19
# 0                  1.00              18.9
# 1                  0.38              20.1
# 2                  0.73              19.0

# %%
#merging SATs participation rate and scores
sat_1718 = sat_17.merge(sat_18, how = 'left', on = 'state')
merged_sats = sat_1718.merge(sat_19, how = 'left', on = 'state')
merged_sats.head(3)
# Out:
#      state  participation_sat_17  ebrw_sat_17  math_sat_17  total_sat_17  \
# 0  Alabama                  0.05          593          572          1165
# 1   Alaska                  0.38          547          533          1080
# 2  Arizona                  0.30          563          553          1116
#
#    participation_sat_18  ebrw_sat_18  math_sat_18  total_sat_18  \
# 0                  0.06          595          571          1166
# 1                  0.43          562          544          1106
# 2                  0.29          577          572          1149
#
#    participation_sat_19  ebrw_sat_19  math_sat_19  total_sat_19
# 0                  0.07          583          560          1143
# 1                  0.41          556          541          1097
# 2                  0.31          569          565          1134

# %% [markdown]
# ## 10. Additional Cleaning.

# %%
#dropping subjects scores for merged data as we do need them for our analysis

merged_act.drop(['english_act_17', 'math_act_17', 'reading_act_17', 'science_act_17'], axis = 1, inplace = True)

# %%
#rearrange the columns for better overview
merged_act = merged_act[['state','participation_act_17', 'participation_act_18','participation_act_19', 
                         'composite_act_17', 'composite_act_18', 'composite_act_19'  ]] 

merged_act.head(3) #check
# Out:
#      state  participation_act_17  participation_act_18  participation_act_19  \
# 0  Alabama                  1.00                  1.00                  1.00
# 1   Alaska                  0.65                  0.33                  0.38
# 2  Arizona                  0.62                  0.66                  0.73
#
#    composite_act_17  composite_act_18  composite_act_19
# 0              19.2              19.1              18.9
# 1              19.8              20.8              20.1
# 2              19.7              19.2              19.0

# %%
#Filter the merged act file for south region only as we will only be analysing the south region

south_region = ('Alabama', 'Arkansas', 'Delaware', 'Florida', 'Georgia', 'Kentucky', 'Louisiana', 'Maryland', 'Mississippi', 
                'North Carolina', 'Oklahoma', 'South Carolina', 'Tennesse', 'Texas', 'Virginia', 'West Virginia', 
                'District of Columbia')

merged_act_south_reg = merged_act[merged_act['state'].isin(south_region)].reset_index(drop = True)

# %%
merged_act_south_reg #check
# Out:
#                    state  participation_act_17  participation_act_18  \
# 0                Alabama                  1.00                  1.00
# 1               Arkansas                  1.00                  1.00
# 2               Delaware                  0.18                  0.17
# 3   District of Columbia                  0.32                  0.32
# 4                Florida                  0.73                  0.66
# 5                Georgia                  0.55                  0.53
# 6               Kentucky                  1.00                  1.00
# 7              Louisiana                  1.00                  1.00
# 8               Maryland                  0.28                  0.31
# 9            Mississippi                  1.00                  1.00
# 10        North Carolina                  1.00                  1.00
# 11              Oklahoma                  1.00                  1.00
# 12        South Carolina                  1.00                  1.00
# ...

# %%
#dropping unnecessary columns from the merged sats data

merged_sats.drop(['ebrw_sat_17', 'math_sat_17', 'ebrw_sat_18', 
                  'math_sat_18', 'ebrw_sat_19', 'math_sat_19' ], axis = 1, inplace = True)

# %%
#rearrange the columns
merged_sats = merged_sats[['state','participation_sat_17', 'participation_sat_18','participation_sat_19', 
                         'total_sat_17', 'total_sat_18', 'total_sat_19'  ]]

# %%
#filter the south region for sats

merged_sats_south_reg = merged_sats[merged_sats['state'].isin(south_region)].reset_index(drop = True)
merged_sats_south_reg #check
# Out:
#                    state  participation_sat_17  participation_sat_18  \
# 0                Alabama                  0.05                  0.06
# 1               Arkansas                  0.03                  0.05
# 2               Delaware                  1.00                  1.00
# 3   District of Columbia                  1.00                  0.92
# 4                Florida                  0.83                  0.56
# 5                Georgia                  0.61                  0.70
# 6               Kentucky                  0.04                  0.04
# 7              Louisiana                  0.04                  0.04
# 8               Maryland                  0.69                  0.76
# 9            Mississippi                  0.02                  0.03
# 10        North Carolina                  0.49                  0.52
# 11              Oklahoma                  0.07                  0.08
# 12        South Carolina                  0.50                  0.55
# ...

# %%
# merge act and sat dataframe
merged_act_sats = merged_act.merge(merged_sats, how = 'left', on = 'state') 
# merge act and sats south region dataframe
merged_act_sats_south_reg = merged_act_south_reg.merge(merged_sats_south_reg, how = 'left', on = 'state')

# %%
merged_act_sats.info() #check
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 51 non-null     object
#  1   participation_act_17  51 non-null     float64
#  2   participation_act_18  51 non-null     float64
#  3   participation_act_19  51 non-null     float64
#  4   composite_act_17      51 non-null     float64
#  5   composite_act_18      51 non-null     float64
#  6   composite_act_19      51 non-null     float64
#  7   participation_sat_17  51 non-null     float64
#  8   participation_sat_18  51 non-null     float64
#  9   participation_sat_19  51 non-null     float64
#  10  total_sat_17          51 non-null     int64
#  11  total_sat_18          51 non-null     int64
#  12  total_sat_19          51 non-null     int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 5.6+ KB

# %%
merged_act_sats_south_reg.info()#check
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 0 to 15
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 16 non-null     object
#  1   participation_act_17  16 non-null     float64
#  2   participation_act_18  16 non-null     float64
#  3   participation_act_19  16 non-null     float64
#  4   composite_act_17      16 non-null     float64
#  5   composite_act_18      16 non-null     float64
#  6   composite_act_19      16 non-null     float64
#  7   participation_sat_17  16 non-null     float64
#  8   participation_sat_18  16 non-null     float64
#  9   participation_sat_19  16 non-null     float64
#  10  total_sat_17          16 non-null     int64
#  11  total_sat_18          16 non-null     int64
#  12  total_sat_19          16 non-null     int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 1.8+ KB

# %% [markdown]
# ## 11. Save cleaned and merged dataframes as csv files.

# %%
merged_sats_south_reg.to_csv('../data/merged_sats_south_reg.csv') # save merged sats data to csv file
merged_act_south_reg.to_csv('../data/merged_act_south_reg.csv') # save merged act data to csv file
merged_act_sats.to_csv('../data/merged_act_sats.csv') # save merged act and sats to csv file. merged data for all states in the US
merged_act_sats_south_reg.to_csv('../data/merged_act_sats_south_reg.csv') # save merged act and sats south region to csv file. states of southern region in US

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.

# %% [markdown]
# #### Dataset Dictionary for merged_act_sats_south_reg.csv
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|act_2017.csv|State Name
# |participation_act_17|float|act_2017.csv|Participation rate
# |composite_act_17|float|act_2017.csv|Average Composite scores
# |---|---|---|---|
# |state|object|act_2018.csv|State Name
# |participation_act_18 |float|act_2018.csv|Participation rate
# |act_comp_18|float|act_2018.csv|Average Composite scores
# |---|---|---|---|
# |state|object|act_2019.csv|State Name
# |participation_act_19|int|act_2019.csv|Participation rate
# |composite_act_19|float|act_2019.csv|Average Composite scores
# |---|---|---|---|
# |state|object|sat_2017.csv|State Name
# |participation_sat_17|float|sat_2017.csv|Participation rate
# |total_sat_17|int|sat_2017.csv|Average Total scores
# |---|---|---|---|
# |state|object|sat_2018.csv|State Name
# |participation_sat_18|int|sat_2018.csv|Participation rate
# |sat_total_18|int|sat_2018.csv|Average Total scores
# |---|---|---|---|
# |state|object|sat_2019.csv|State Name
# |participation_sat_19|int|sat_2019.csv|Participation rate
# |sat_total_19|int|sat_2019.csv|Average Total scores

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### 1. Summary Statistics

# %%
merged_sats_south_reg.describe().T
# Out:
#                       count         mean        std     min        25%  \
# participation_sat_17   16.0     0.423750   0.364470    0.02     0.0475
# participation_sat_18   16.0     0.433125   0.345634    0.03     0.0575
# participation_sat_19   16.0     0.530000   0.387728    0.03     0.0675
# total_sat_17           16.0  1095.812500  90.316642  950.00  1040.2500
# total_sat_18           16.0  1101.562500  84.170437  977.00  1054.5000
# total_sat_19           16.0  1075.312500  95.677736  943.00   995.5000
#
#                            50%       75%     max
# participation_sat_17     0.495     0.660     1.0
# participation_sat_18     0.535     0.685     1.0
# participation_sat_19     0.680     0.850     1.0
# total_sat_17          1072.500  1173.250  1247.0
# total_sat_18          1089.000  1166.750  1248.0
# total_sat_19          1058.000  1141.500  1237.0

# %% [markdown]
# The following are my observations for the SAT summary statistics:
# * We have 16 states in the southern region of the united states. these states are used for our anaylsis
#
# Participation Rates
#
# * The maximum participant rates for SAT from 2017 to 2019 are 100 % in each year whilst the minimum participant rate is 2%, 3% and 3% respectively.
# * the mean of the participant rates are 0.423750, 0.43312 and 0.53 and standard deviation of 0.365570, 0.345634 and 0.387728 respectively from year 2017 to 2019. this indicates that for the year 2017 and 2018, the participation rates are slightly below the median which  whilst participation rate for year 2019 indicates slightly above average
# * It is worth noting that the 75% percentile for participant rate for 2019 is 85% which is high and a steep climb as compared to the previous years
# * The standard deviation of each year indicates the ranges between 0.345634 to 0.387728 which is slighly consistent in the deviation
# * 2019 data inidicates the most increased participation
#
# Total SAT Scores
#
# *  The Maximum scores are 1247, 1248 and 1237, minumum scores 950, 977, 943 for the years 2017 to 2019 respectively. this indicates for the year 2018, students fared the best in scores among the 3 years withh 2019 faring the worst. this maybe relative to the increased participation and larger pool of students in year 2019.
# * At the 75% percentile, students in 2017 fared much better than 2018 and 2019
# * looking at the mean of the score and 50% percentile, 2018 students fared better in their averages

# %%
merged_act_south_reg.describe().T
# Out:
#                       count       mean       std     min      25%     50%  \
# participation_act_17   16.0   0.718125  0.322495   0.180   0.4175   0.865
# participation_act_18   16.0   0.708125  0.326950   0.170   0.4175   0.830
# participation_act_19   16.0   0.664375  0.337816   0.130   0.3725   0.660
# composite_act_17       16.0  20.407812  1.968073  18.225  19.1750  19.650
# composite_act_18       16.0  20.581250  1.897443  18.300  19.1750  20.050
# composite_act_19       16.0  20.537500  1.966003  18.400  18.9000  19.950
#
#                          75%   max
# participation_act_17   1.000   1.0
# participation_act_18   1.000   1.0
# participation_act_19   1.000   1.0
# composite_act_17      20.875  24.2
# composite_act_18      21.675  23.9
# composite_act_19      21.625  24.1

# %% [markdown]
# The following are my observations for the ACT summary statistics:
#
# Participation Rates
#
# * The maximum participant rates for ACT from 2017 to 2019 are 100 % in each year whilst the minimum participant rate is 18%, 17% and 13% respectively.
# * The mean of the participant rates are 0.718125, 0.708125 and 0.664375 and standard deviation of 0.322495, 0.326950 and 0.337816 respectively from year 2017 to 2019. the participation rates are above median for each year
# * It is worth noting that the 75% percentile for participant rate for all 3 years is 100% which is high and consistent
# * The standard deviation of each year ranging from 0.322495 - 0.337816, indicates low standard deviation, which signals a good spread of data for participation rate
# * There is a drop in the 50 percentile however this shows that more students jumped to the 75% and above which inidicates more take up rate
#
# Composite Scores
#
# * The Maximum scores are 24.2, 23.9 and 24.1, minumum scores 18.225, 18.30, 18.40 for the years 2017 to 2019 respectively. this indicates for the year 2017, students fared the best in scores among the 3 years with 2019 faring the worst. this maybe relative to the increased participation and larger pool of students in year 2019.
# * At the 75% percentile, students in 2018 fared much better than 2018 and 2019
# * Looking at the mean of the score and 50% percentile, 2018 students fared better in their averages

# %%
merged_act_sats_south_reg.describe().T
# Out:
#                       count         mean        std      min        25%  \
# participation_act_17   16.0     0.718125   0.322495    0.180     0.4175
# participation_act_18   16.0     0.708125   0.326950    0.170     0.4175
# participation_act_19   16.0     0.664375   0.337816    0.130     0.3725
# composite_act_17       16.0    20.407812   1.968073   18.225    19.1750
# composite_act_18       16.0    20.581250   1.897443   18.300    19.1750
# composite_act_19       16.0    20.537500   1.966003   18.400    18.9000
# participation_sat_17   16.0     0.423750   0.364470    0.020     0.0475
# participation_sat_18   16.0     0.433125   0.345634    0.030     0.0575
# participation_sat_19   16.0     0.530000   0.387728    0.030     0.0675
# total_sat_17           16.0  1095.812500  90.316642  950.000  1040.2500
# total_sat_18           16.0  1101.562500  84.170437  977.000  1054.5000
# total_sat_19           16.0  1075.312500  95.677736  943.000   995.5000
#
# ...

# %% [markdown]
# The following are my observations for the SAT and ACT summary statistics:
#
# Participation Rates
#
# * The maximum participant rates for ACT and SAT from 2017 to 2019 are 100 % in each year whilst the minimum participant rate are  18%, 17% and 13% for ACT and 2%, 3% and 3% for SAT respectively. this indicates that SAT has lesser minimum participation than ACT.
# * The mean of the ACT participant rates are 0.718125, 0.708125 and 0.664375 arespectively from year 2017 to 2019. the mean of the SAT participant rates are 0.423750, 0.43312 and 0.53 from year 2017 to 2019. the participation means for ACT is larger than SAT and above the median value. this inidicates students prefer the ACT over SAT in the southern region
# * It is worth noting that the 75% percentile for participant rate for all 3 years fo ACT is 100% and the 50% percentile which are higher and consistent over and above the SAT participation rates. another indicator that more percentage of students prefers in the south ACT over SAT

# %% [markdown]
# ### 2. Use a dictionary comprehension to apply the standard deviation function you create in part 1 to each numeric column in the dataframe. No loops.

# %%
def calc_stdev(list_numbers):
    sum_sqr = 0
    avg = sum(list_numbers)/len(list_numbers)
    for x in list_numbers:
        parenthesis = (x - avg)**2
        sum_sqr = sum_sqr + parenthesis
    before_square_root = (sum_sqr) * (1/len(list_numbers))
    std = before_square_root**0.5
    
    return std

# %%
#for numeric value in the merged SAT and ACT dataframe 
#insert std function 
for col in list(merged_act_sats_south_reg):
    if merged_act_sats_south_reg[col].dtype != 'O':
        std = calc_stdev(merged_act_sats_south_reg[col])
        print(f'standard deviation for {col} is {std}')
# Out:
# standard deviation for participation_act_17 is 0.3122542783934273
# standard deviation for participation_act_18 is 0.316567898522576
# standard deviation for participation_act_19 is 0.3270888401871883
# standard deviation for composite_act_17 is 1.905578134672979
# standard deviation for composite_act_18 is 1.8371917258413721
# standard deviation for composite_act_19 is 1.9035739413009416
# standard deviation for participation_sat_17 is 0.3528964968655824
# standard deviation for participation_sat_18 is 0.3346587581029368
# standard deviation for participation_sat_19 is 0.3754164354420301
# standard deviation for total_sat_17 is 87.44871264775715
# standard deviation for total_sat_18 is 81.49767538862689
# standard deviation for total_sat_19 is 92.63956953564713

# %% [markdown]
# ### 3. Investigate trends in the data.

# %% [markdown]
# #### Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?

# %%
# find the min value of ACT 17, ACT 18 and ACT 19 participation rate
merged_act_sats_south_reg[['participation_act_17', 'participation_act_18', 'participation_act_19']].min()
# Out:
# participation_act_17    0.18
# participation_act_18    0.17
# participation_act_19    0.13
# dtype: float64

# %%
# find the state with the min value of participation rate of 0.18 in ACT 17
merged_act_sats_south_reg[merged_act_sats_south_reg['participation_act_17'] == 0.18]['state']
# Out:
# 2    Delaware
# Name: state, dtype: object

# %%
# find the state with the min value of participation rate 0.17 in ACT 18
merged_act_sats_south_reg[merged_act_sats_south_reg['participation_act_18'] == 0.17]['state']
# Out:
# 2    Delaware
# Name: state, dtype: object

# %%
# find the state with the min value of participation rate of 0.13 in ACT 19
merged_act_sats_south_reg[(merged_act_sats_south_reg['participation_act_19'] == 0.13)]['state']
# Out:
# 2    Delaware
# Name: state, dtype: object

# %%
# find the max value of ACT 17 , ACT 18 and ACT 19 participation rate
merged_act_sats_south_reg[['participation_act_17', 'participation_act_18', 'participation_act_19']].max()
# Out:
# participation_act_17    1.0
# participation_act_18    1.0
# participation_act_19    1.0
# dtype: float64

# %%
# find the states with the max value of participation rate of 1.0 in ACT 17
merged_act_sats_south_reg[merged_act_sats_south_reg['participation_act_17'] == 1.0]['state']
# Out:
# 0            Alabama
# 1           Arkansas
# 6           Kentucky
# 7          Louisiana
# 9        Mississippi
# 10    North Carolina
# 11          Oklahoma
# 12    South Carolina
# Name: state, dtype: object

# %%
# find the states with the max value of participation rate of 1.0 in ACT 18
merged_act_sats_south_reg[merged_act_sats_south_reg['participation_act_18'] == 1.0]['state']
# Out:
# 0            Alabama
# 1           Arkansas
# 6           Kentucky
# 7          Louisiana
# 9        Mississippi
# 10    North Carolina
# 11          Oklahoma
# 12    South Carolina
# Name: state, dtype: object

# %%
# find the states with the max values of participation rate of 1.0 in ACT 19
merged_act_sats_south_reg[(merged_act_sats_south_reg['participation_act_19'] == 1.0)]['state']
# Out:
# 0            Alabama
# 1           Arkansas
# 6           Kentucky
# 7          Louisiana
# 9        Mississippi
# 10    North Carolina
# 11          Oklahoma
# Name: state, dtype: object

# %%
# find the min value of participation rate of SAT 17, SAT 18 and SAT 19 participation rate
merged_act_sats_south_reg[['participation_sat_17', 'participation_sat_18','participation_sat_19']].min()
# Out:
# participation_sat_17    0.02
# participation_sat_18    0.03
# participation_sat_19    0.03
# dtype: float64

# %%
# find the states with the min value of participation rate of 0.02 SAT score in 2017
merged_act_sats_south_reg[merged_act_sats_south_reg['participation_sat_17'] == 0.02]['state']
# Out:
# 9    Mississippi
# Name: state, dtype: object

# %%
# find the states with the min value of participation rate of 0.02 SAT score in 2018
merged_act_sats_south_reg[merged_act_sats_south_reg['participation_sat_17'] == 0.03]['state']
# Out:
# 1    Arkansas
# Name: state, dtype: object

# %%
# find the states with the min value of participation rate of 0.02 SAT score in 2019
merged_act_sats_south_reg[merged_act_sats_south_reg['participation_sat_19'] == 0.03]['state']
# Out:
# 9    Mississippi
# Name: state, dtype: object

# %%
# find the max value of SAT 17, SAT 18 and SAT 19 participation rate
merged_act_sats_south_reg[['participation_sat_17', 'participation_sat_18', 'participation_sat_19']].max()
# Out:
# participation_sat_17    1.0
# participation_sat_18    1.0
# participation_sat_19    1.0
# dtype: float64

# %%
# find the states with the max value of participation rate of 1.0 SAT score in 2017
merged_act_sats_south_reg[merged_act_sats_south_reg['participation_sat_17'] == 1.0]['state']
# Out:
# 2                Delaware
# 3    District of Columbia
# Name: state, dtype: object

# %%
# find the states with the max value of participation rate of 1.0 SAT score in 2018
merged_act_sats_south_reg[merged_act_sats_south_reg['participation_sat_18'] == 1.0]['state']
# Out:
# 2    Delaware
# Name: state, dtype: object

# %%
# find the states with the max value of participation rate of 1.0 SAT score in 2019
merged_act_sats_south_reg[merged_act_sats_south_reg['participation_sat_19'] == 1.0]['state']
# Out:
# 2    Delaware
# 4     Florida
# Name: state, dtype: object

# %% [markdown]
# The Southern region state with the least ACT participation rates from 2017 to 2019 were:
#
# |S/N|State|Participation rate|Year|
# |---|---|---|---|
# |1|Delware|0.18|2017|
# |2|Delware|0.17|2018|
# |3|Delware|0.13|2019|
#
#
# The Southern region states with the most ACT participation rates of 1.0 from 2017 to 2019 were:
#
# |S/N|2017|2018|2019|
# |---|---|---|---|
# |1|Alabama|Alabama|Alabama|
# |2|Arkansas|Arkansas|Arkansas|
# |3|Kentucky|Kentucky|Kentucky|
# |4|Louisiana|Louisiana|Louisiana|
# |5|Mississippi|Mississippi|Mississippi|
# |6|North Carolina|North Carolina|North Carolina|
# |7|Oklahoma|Oklahoma|Oklahoma|
# |8|South Carolina|South Carolina|---|
#
#
# The Southern region state with the least SAT participation rates from 2017 to 2019 were:
#
# |S/N|State|Participation rate|Year|
# |---|---|---|---|
# |1|Mississippi|0.02|2017|
# |2|Arkansas|0.03|2018|
# |3|Mississippi|0.03|2019|
#
# The Southern region states with the most SAT participation rates of 1.0 from 2017 to 2019 were:
#
# |S/N|2017|2018|2019|
# |---|---|---|---|
# |1|Delware|Delaware|Delaware|
# |2|District of Columbia|---|Florida|

# %% [markdown]
# *  from the data gathered, Delware participates more likely in the SAT test as compareed to ACT test. They have been consistently for the 3 years participating in the SAT test with 100% participation rate and the least participating in the ACT test. information gathered from external sources stated that Delaware had replaced the state's Delaware's Smarter Assessment state test for 11th graders with the SAT to streamline standardized testing and providing increased access to the SAT such as state sponsered SAT test once for every student. The state also utilises the SAT to judge schools based on how their students perform. and the state from 2016, requires all schools in Delaware to administer the SAT test. hence the 100% participation rate. the outliers participating in the ACT maybe students taking both the ACT and SAT to increase their chances to qualify for the university that they want apply in.
#
# source: https://whyy.org/articles/sat-to-the-rescue-why-delaware-and-other-states-are-embracing-a-new-role-for-an-old-test/
# https://www.doe.k12.de.us/Page/2717
#
# *  Mississipppi and Arkansas students prefered to participate in the ACT test as compared to SAT test. for Arkansas, though the ACT is not required for their students, all districts in Arkansas are to provide ACT testing instead of the SAT. hence the easier access to ACT, driving the ACT partcipation rate up, whilst for mississippi, students graduating are to take up the MAAP and the ACT in order to graduate. which again drives up the participation rate. both states has the least support or access to SAT thus the low take up rate for SAT
#
# source: https://www.edweek.org/teaching-learning/which-states-require-students-to-take-the-sat-or-act
#
#
# * Alabama, Arkansas, Kentucky, Louisiana, Mississippi, North Carolina, Oklahoma has full participation rates for ACT test consistently for 3 years. this is evident from the state's direction of mandatory ACT testing requirement for all of the states listed least Oklahoma( District decides either SAT or ACT testing) and Arkansas (explained in the earlier statement) which drove up the participation rate to 100% and consistently. wherelse for Oklahoma, the district would choose which testing to be taken. we would presume that Oklahoma opted for ACT for the years 2017 -2019 consistency and evidently with the participation rate of 100% for ACT for the 3 years.
#
# source: https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice
#
# *  South Carolina was participating 100% consistent ACT participantion for 2 years untill 2019, it dipped to 78%. however the SAT participation rate increase by 13% from 2018 to 2019. hence we see that there was a shift in students adopting the SAT testing instead of the ACT.
#
# *  We can see that florida participation rate jumped to 100% in 2019, this shift is largely due to the ease of access to the SAT through SAT school day.
#
# source: https://www.orlandosentinel.com/news/education/os-ne-sat-scores-florida-20190924-2ycpuogc2ndkrkwzdrkrjgrg64-story.html

# %% [markdown]
# #### Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
# we will also like to compare the participation rates for this analysis

# %%
# find the lowest composite score and their participation rate in ACT 2017
merged_act_sats_south_reg.sort_values('composite_act_17')[['state', 'composite_act_17', 'participation_act_17']].head(3)
# Out:
#              state  composite_act_17  participation_act_17
# 8         Maryland            18.225                  0.28
# 9      Mississippi            18.600                  1.00
# 12  South Carolina            18.700                  1.00

# %%
# find the lowest composite score and their participation rate in ACT 2018
merged_act_sats_south_reg.sort_values('composite_act_18')[['state', 'composite_act_18','participation_act_18']].head(3)
# Out:
#              state  composite_act_18  participation_act_18
# 12  South Carolina              18.3                   1.0
# 9      Mississippi              18.6                   1.0
# 0          Alabama              19.1                   1.0

# %%
# find the lowest composite score and their participation rate in ACT 2019
merged_act_sats_south_reg.sort_values('composite_act_19')[['state', 'composite_act_19', 'participation_act_19']].head()
# Out:
#              state  composite_act_19  participation_act_19
# 9      Mississippi              18.4                  1.00
# 7        Louisiana              18.8                  1.00
# 12  South Carolina              18.8                  0.78
# 0          Alabama              18.9                  1.00
# 11        Oklahoma              18.9                  1.00

# %%
# find the highest composite score and their participation rate in ACT 2017
merged_act_sats_south_reg.sort_values('composite_act_17', ascending = False)[['state', 'composite_act_17', 'participation_act_17']].head(3)
# Out:
#                    state  composite_act_17  participation_act_17
# 3   District of Columbia              24.2                  0.32
# 2               Delaware              24.1                  0.18
# 14              Virginia              23.8                  0.29

# %%
# find the highest composite score and their participation rate in ACT 2018
merged_act_sats_south_reg.sort_values('composite_act_18', ascending = False)[['state', 'composite_act_18', 'participation_act_18']].head(3)
# Out:
#                    state  composite_act_18  participation_act_18
# 14              Virginia              23.9                  0.24
# 2               Delaware              23.8                  0.17
# 3   District of Columbia              23.6                  0.32

# %%
# find the highest composite score and their participation rate in ACT 2019
merged_act_sats_south_reg.sort_values('composite_act_19', ascending = False)[['state', 'composite_act_19', 'participation_act_19']].head()
# Out:
#                    state  composite_act_19  participation_act_19
# 2               Delaware              24.1                  0.13
# 14              Virginia              24.0                  0.21
# 3   District of Columbia              23.5                  0.32
# 8               Maryland              22.3                  0.28
# 5                Georgia              21.4                  0.49

# %%
# find the lowest total score and their participation rate in SAT 2017
merged_act_sats_south_reg.sort_values('total_sat_17')[['state', 'total_sat_17', 'participation_sat_17']].head()
# Out:
#                    state  total_sat_17  participation_sat_17
# 3   District of Columbia           950                  1.00
# 2               Delaware           996                  1.00
# 4                Florida          1017                  0.83
# 13                 Texas          1020                  0.62
# 11              Oklahoma          1047                  0.07

# %%
# find the lowest total score and their participation rate in SAT 2018
merged_act_sats_south_reg.sort_values('total_sat_18')[['state', 'total_sat_18', 'participation_sat_18']].head()
# Out:
#                    state  total_sat_18  participation_sat_18
# 3   District of Columbia           977                  0.92
# 2               Delaware           998                  1.00
# 15         West Virginia           999                  0.28
# 13                 Texas          1032                  0.66
# 11              Oklahoma          1062                  0.08

# %%
# find the lowest total score and their participation rate in SAT 2019
merged_act_sats_south_reg.sort_values('total_sat_19')[['state', 'total_sat_19','participation_sat_19']].head()
# Out:
#                    state  total_sat_19  participation_sat_19
# 15         West Virginia           943                  0.99
# 11              Oklahoma           963                  0.22
# 3   District of Columbia           975                  0.94
# 2               Delaware           985                  1.00
# 4                Florida           999                  1.00

# %%
# find the highest total score and their participation rate in SAT 2017
merged_act_sats_south_reg.sort_values('total_sat_17', ascending = False)[['state', 'total_sat_17','participation_sat_17']].head()
# Out:
#          state  total_sat_17  participation_sat_17
# 6     Kentucky          1247                  0.04
# 9  Mississippi          1242                  0.02
# 1     Arkansas          1208                  0.03
# 7    Louisiana          1198                  0.04
# 0      Alabama          1165                  0.05

# %%
# find the highest total score and their participation rate in SAT 2018
merged_act_sats_south_reg.sort_values('total_sat_18', ascending = False)[['state', 'total_sat_18', 'participation_sat_18']].head(3)
# Out:
#          state  total_sat_18  participation_sat_18
# 6     Kentucky          1248                  0.04
# 9  Mississippi          1236                  0.03
# 7    Louisiana          1210                  0.04

# %%
# find the highest total score and their participation rate in SAT 2019
merged_act_sats_south_reg.sort_values('total_sat_19', ascending = False)[['state', 'total_sat_19', 'participation_sat_19']].head(3)
# Out:
#          state  total_sat_19  participation_sat_19
# 9  Mississippi          1237                  0.03
# 6     Kentucky          1232                  0.04
# 7    Louisiana          1200                  0.05

# %% [markdown]
# The Southern region states with the lowest ACT composite scores from 2017 to 2019 were:
#
# | s/n |      state     | composite score | Participation Rate | Year |
# |:---:|:--------------:|:---------------:|:------------------:|:----:|
# |  1  |   Mississippi  |       18.6      |         1.0        | 2017 |
# |  2  | South Carolina |       18.3      |         1.0        | 2018 |
# |  3  |   Mississippi  |       18.4      |        1.00        | 2019 |
#
# The Southern region states with the highest ACT composite scores from 2017 to 2019 were:
#
# | s/n |         state        | composite score | Participation Rate | Year |
# |:---:|:--------------------:|:---------------:|:------------------:|:----:|
# |  1  | District of Columbia |            24.2 |        0.32        | 2017 |
# |  2  |       Virginia       |            23.9 |        0.24        | 2018 |
# |  3  |       Delaware       |            24.1 |        0.13        | 2019 |
#
# The Southern region states with the lowest SAT total scores from 2017 to 2019 were:
#
# | s/n |         state        | total score | Participation Rate | Year |
# |:---:|:--------------------:|:-----------:|:------------------:|:----:|
# |  1  | District of Columbia |         950 |         1.0        | 2017 |
# |  2  | District of Columbia |         977 |        0.92        | 2018 |
# |  3  |     West Virginia    |         943 |        0.99        | 2019 |
#
# The Southern region states with the highest SAT total scores from 2017 to 2019 were:
#
# | s/n |    state    | total score | Participation Rate | Year |
# |:---:|:-----------:|:-----------:|:------------------:|:----:|
# |  1  |   Kentucky  |        1247 |        0.04        | 2017 |
# |  2  |   Kentucky  |        1248 |        0.04        | 2018 |
# |  3  | Mississippi |        1237 |        0.03        | 2019 |

# %% [markdown]
# * From the data collected and filtered. The ACT scores of the states with the lowest for the 3 years had participant rate with 100% while the ACT scores with the highest ACT scores had low participant rates. this is evident that higher take up rate of the ACT would result in lower ACT scores due to the increased population size or the willingness / preparedness of the students ability to score higher in the ACT scores
#
#
# *  The states scoring the lowest SAT scores over the 3 years had high participant rates while the states scoring the highest had low participation rates. this is somehow similar to the ACT findings with the higher the participants, scores will be lower. where else we might see that allowing the students to choose whether he wants to participate in the state testing, he/she is more motivated to better prepare himself and the willingness to take up the test and score higher in the tests

# %% [markdown]
# #### Do any states show have >50% participation on both tests each year?

# %%
# filter the states with more that 50% ACT and participation for year 2017
# Filtering in df using vectors of booleans to describe inclusion or exclusion. True means in, False means out.

southstates_more_50_17 = merged_act_sats_south_reg[(merged_act_sats_south_reg['participation_act_17'] > 0.5) 
                                                   & (merged_act_sats_south_reg['participation_sat_17'] > 0.5)]

southstates_more_50_17[['state','participation_act_17', 'participation_sat_17' ]]
# Out:
#      state  participation_act_17  participation_sat_17
# 4  Florida                  0.73                  0.83
# 5  Georgia                  0.55                  0.61

# %%
# filter the states with more that 50% ACT and participation for year 2018
southstates_more_50_18 = merged_act_sats_south_reg[(merged_act_sats_south_reg['participation_act_18'] > 0.5) 
                                                   & (merged_act_sats_south_reg['participation_sat_18'] > 0.5)]

southstates_more_50_18[['state','participation_act_18', 'participation_sat_18' ]]
# Out:
#              state  participation_act_18  participation_sat_18
# 4          Florida                  0.66                  0.56
# 5          Georgia                  0.53                  0.70
# 10  North Carolina                  1.00                  0.52
# 12  South Carolina                  1.00                  0.55

# %%
# filter the states with more that 50% ACT and participation for year 2019
southstates_more_50_19 = merged_act_sats_south_reg[(merged_act_sats_south_reg['participation_act_19'] > 0.5) 
                                                   & (merged_act_sats_south_reg['participation_sat_19'] > 0.5)]

southstates_more_50_19[['state','participation_act_19', 'participation_sat_19' ]]
# Out:
#              state  participation_act_19  participation_sat_19
# 4          Florida                  0.54                  1.00
# 10  North Carolina                  1.00                  0.51
# 12  South Carolina                  0.78                  0.68

# %%
#filter the states with > 50% participation rates for both tests from 2017 to 2019
merged_act_sats_south_reg[(merged_act_sats_south_reg['participation_act_17'] > 0.5) 
                            & (merged_act_sats_south_reg['participation_sat_17'] > 0.5)
                         & (merged_act_sats_south_reg['participation_act_18'] > 0.5) 
                        & (merged_act_sats_south_reg['participation_sat_18'] > 0.5)
                         & (merged_act_sats_south_reg['participation_act_19'] > 0.5) 
                        & (merged_act_sats_south_reg['participation_sat_19'] > 0.5)]
# Out:
#      state  participation_act_17  participation_act_18  participation_act_19  \
# 4  Florida                  0.73                  0.66                  0.54
#
#    composite_act_17  composite_act_18  composite_act_19  participation_sat_17  \
# 4              19.8              19.9              20.1                  0.83
#
#    participation_sat_18  participation_sat_19  total_sat_17  total_sat_18  \
# 4                  0.56                   1.0          1017          1099
#
#    total_sat_19
# 4           999

# %%
#filter for states with less than 50% participation rates in any given year
merged_act_sats_south_reg[(merged_act_sats_south_reg['participation_act_17'] < 0.5) 
                            & (merged_act_sats_south_reg['participation_sat_17'] < 0.5)
                         | (merged_act_sats_south_reg['participation_act_18'] < 0.5) 
                        & (merged_act_sats_south_reg['participation_sat_18'] < 0.5)
                        | (merged_act_sats_south_reg['participation_act_19'] < 0.5) 
                        & (merged_act_sats_south_reg['participation_sat_19'] < 0.5)]
# Out:
# Empty DataFrame
# Columns: [state, participation_act_17, participation_act_18, participation_act_19, composite_act_17, composite_act_18, composite_act_19, participation_sat_17, participation_sat_18, participation_sat_19, total_sat_17, total_sat_18, total_sat_19]
# Index: []

# %% [markdown]
# #### Find the least participation rate state for sat and act in 2019

# %%
#filter participation rates to less than 75% for sat and act
less_than_75perc = merged_act_sats_south_reg[(merged_act_sats_south_reg['participation_act_19'] <.75) 
& (merged_act_sats_south_reg['participation_sat_19']< 0.75)]

# find the lowest state participant rates for SAT and ACT in 2019
less_than_75perc.nsmallest(3,['participation_act_19','participation_sat_19'])[['state','participation_act_19','participation_sat_19']]
# Out:
#        state  participation_act_19  participation_sat_19
# 14  Virginia                  0.21                  0.68
# 13     Texas                  0.39                  0.68
# 5    Georgia                  0.49                  0.71

# %% [markdown]
# Yhe following states have more than 50% participation rate for both ACT and SAT for the following years:
#
# 2017
#
# *  Florida
# *  Georgia
#
# 2018
#
# *  Florida
# *  Georgia
# *  North Carolina
# *  South Carolina
#
# 2019
#
# *  Florida
# *  North Carolina
# *  South Carolina

# %% [markdown]
# *  For florida, though the SAT and ACT tests are not mandatory for students graduating, they will have to pass their state exams or to attain a certain score in the SAT or ACT before they graduates they have more than 50 % participation rates for both tests. this may indicate that florida students aspires to go to university utilising the ACT and SAT more than any other states.
#
# *  For georgia, SAT/ACT tests are not mandatory. they will have to just pass their Georgia Milestones end-of-course exams or the State tests to graduate. this again indicates that they will prefer more to take up the SAT/ACT exams
#
# *  Interestingly, Florida, Georgia, North Carolina, and South Carolina are coastal states. this indicates that coastal states are more likely to take up the SAT/ACT test with more than 50% participant rates
#
# * Florida is the only state with more than 50 % participation for the 3 years
#
# * There were no states with less than 50% participation rate
#
# * Virginia was the lowest participation rate for SAT and ACT in 2019

# %% [markdown]
# #### Which states have the highest significant changes for SAT and ACT scores from 2017 to 2019?

# %%
# significant change of ACT participants from 2017 to 2019
# create a new column 'significatn_change' which houses the value of act participant 19 - act participant 17
merged_act_sats_south_reg['act_significant_change'] = (merged_act_sats_south_reg['participation_act_19'] - 
                                                       merged_act_sats_south_reg['participation_act_17'] )


#sort the values in act_significant_change_18 from highest to lowest
merged_act_sats_south_reg.sort_values('act_significant_change', ascending = False)[['state', 'act_significant_change']].head()
# Out:
#                   state  act_significant_change
# 0               Alabama                     0.0
# 1              Arkansas                     0.0
# 3  District of Columbia                     0.0
# 6              Kentucky                     0.0
# 7             Louisiana                     0.0

# %%
#sort the values in act_significant_change_18 from lowest to highest
merged_act_sats_south_reg.sort_values('act_significant_change', ascending = True)[['state', 'act_significant_change']]
# Out:
#                    state  act_significant_change
# 12        South Carolina                   -0.22
# 15         West Virginia                   -0.20
# 4                Florida                   -0.19
# 14              Virginia                   -0.08
# 5                Georgia                   -0.06
# 13                 Texas                   -0.06
# 2               Delaware                   -0.05
# 0                Alabama                    0.00
# 1               Arkansas                    0.00
# 3   District of Columbia                    0.00
# 6               Kentucky                    0.00
# 7              Louisiana                    0.00
# 8               Maryland                    0.00
# 9            Mississippi                    0.00
# 10        North Carolina                    0.00
# 11              Oklahoma                    0.00

# %%
# significant change of SAT participants from 2017 to 2019
# create a new column 'significatn_change_18' which houses the value of sat participant 19 - sat participant 17
merged_act_sats_south_reg['sat_significant_change'] = (merged_act_sats_south_reg['participation_sat_19']-
merged_act_sats_south_reg['participation_sat_17'] )

#sort the values in sat_significant_change_18 from highest to lowest
merged_act_sats_south_reg.sort_values('sat_significant_change', ascending = False)[['state', 'sat_significant_change']].head()
# Out:
#              state  sat_significant_change
# 15   West Virginia                    0.85
# 12  South Carolina                    0.18
# 4          Florida                    0.17
# 11        Oklahoma                    0.15
# 8         Maryland                    0.13

# %%
#sort the values in sat_significant_change_18 from lowest to highest
merged_act_sats_south_reg.sort_values('sat_significant_change', ascending = True)[['state', 'sat_significant_change']].head()
# Out:
#                   state  sat_significant_change
# 3  District of Columbia                   -0.06
# 2              Delaware                    0.00
# 6              Kentucky                    0.00
# 9           Mississippi                    0.01
# 7             Louisiana                    0.01

# %% [markdown]
# * There is no significant change in increase for ACT participant rates from 2017 to 2019, however there is a decreased in participation rate for west virginia and South carolina. looking at the SAT participation rates, West virginia had a significant increase in participation rate. Florida and South carolina had also an increase in SAT participation rate. West virginia had implemented mandatory SAT testing in 2018/19 for graduating students which cause the skyrocket increased in participation rates while Florida and South Carolina had a shift in participation rate from the ACT to SAT testing participatin rates.
#
#
# * we also can analyse that the SAT is increasingly gaining traction in the participation rates and ACT participation rates are slightly declining

# %% [markdown]
# ## Visualize the Data

# %% [markdown]
# #### 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.

# %%
plt.figure(figsize=(12,12))
plt.title('Correlation of ACT and SATs in the Southern Region\n')
sns.heatmap(merged_act_sats_south_reg.corr(), annot = True, cmap = 'coolwarm');

# %% [markdown]
# * Participation rates among the ACT for the 3 years are strongly positively correlated as indicated in the heatmap where the participation rate increases or decreases, the other participation rates follows. this observation is similar to SAT participations rates for the 3 years
# * ACT and SAT participcation rates are strongly negatively correlated. where one variable is associated with a decrease in the other variable. hence we can assume that if ACT participation rates increase, SAT participation rates will decrease and vice versa.
# * ACT scores and ACT participation rates are negeatively correlated. we can assume that if the ACT participation increase, ACT scores will be fared lowered. this observation is similar for SAT scores and SAT participation rates

# %% [markdown]
# #### 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
#Define function to plot histograms displaying comparative distributions of variables

def subplot_hist(dataframe, list_of_columns, list_of_titles, list_of_xlabels,figsize_t, bins_range = 5):
    plt.style.use('bmh')
    
    nrows = int(np.ceil(len(list_of_columns)/2)) # This makes sure we have enough rows
    fig, ax = plt.subplots(figsize = figsize_t, nrows = 2, ncols = 3) # specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, this makes it easier to iterate
    for i, column in enumerate(list_of_columns): # set index value to get into all our lists
            ax[i].hist(dataframe[column],bins=bins_range) 
            ax[i].set_title(list_of_titles[i], fontsize = 14)# Set titles, labels for each subplot
            ax[i].set_xlabel(list_of_xlabels[i], fontsize = 12)
            ax[i].set_ylabel('Number of States', fontsize = 12)
            ax[i].vlines(x = np.mean(dataframe[column]), ymin = 0, ymax = 10, color = 'r') # set meanline on subplots
    plt.tight_layout(pad = 2) #create spacing between plots

# %%
# plotting of ACT and SAT participation rates for year 2017 to 2019

col_lst = ['participation_act_17', 'participation_act_18', 'participation_act_19', 
          'participation_sat_17', 'participation_sat_18', 'participation_sat_19']
title_lst = ['ACT 2017', 'ACT 2018', 'ACT 2019',
            'SAT 2017', 'SAT 2018', 'SAT 2019']
x_labels = ['Participation Rate', 'Participation Rate', 'Participation Rate',
            'Participation Rate', 'Participation Rate', 'Participation Rate']


subplot_hist(merged_act_sats_south_reg, col_lst, title_lst, x_labels, (15, 8)  )
plt.suptitle('SOUTHERN STATES AVERAGE PARTICIPATION RATE', fontweight = 'bold', fontsize = 16)
plt.subplots_adjust(top=0.9);

# %% [markdown]
# * From the ACT and SAT average participation, we can see that the mean participation for ACT is skewed towards the right and above the average median and higher than SAT's participation. hence, we can say that the average participation for ACT is higer than SAT. we also can see that SAT average participation rate is slowly gaining traction for 2019.
# * we also can see that there is a larger group high participants in the ACT and low participants in the SAT group.
#
# * hence we can assume that there are more students in the south taking the ACT over the SAT.

# %%
# Plotting ACT composite and SAT total scores from 2017 to 2019

col_lst_scores = ['composite_act_17', 'composite_act_18', 'composite_act_19', 
          'total_sat_17', 'total_sat_18', 'total_sat_19']
title_lst_scores = ['ACT 2017', 'ACT 2018', 'ACT 2019',
            'SAT 2017', 'SAT 2018', 'SAT 2019']
x_labels_scores = ['Scores', 'Scores', 'Scores',
            'Scores', 'Scores', 'Scores']


subplot_hist(merged_act_sats_south_reg, col_lst_scores, title_lst_scores, x_labels_scores, (15, 8)  )
plt.suptitle('SOUTHERN STATES AVERAGE SCORES\n\n', fontweight = 'bold', fontsize = 16)
plt.subplots_adjust(top=0.9);

# %% [markdown]
# * while, more students in the south are taking ACT over the SAT, their scores were faring below the average mean and SAT students were faring slightly better in than ACT students.
# * we can see the larger group of low scoring scores in the ACT as compared to the SAT which is fared slightly better

# %%
# Plotting ACT  ACT composite scores from 2017 to 2019

col_lst_scores = ['participation_act_17', 'participation_act_18', 'participation_act_19',
                    'composite_act_17', 'composite_act_18', 'composite_act_19']
title_lst_scores = ['ACT Participation 2017', 'ACT Participation 2018', 'ACT Participation 2019',
            'ACT Scores 2017', 'ACT Scores 2018', 'ACT Scores 2019']
x_labels_scores = ['Participation Rate', 'Participation Rate', 'Participation Rate',
            'Scores', 'Scores', 'Scores']


subplot_hist(merged_act_sats_south_reg, col_lst_scores, title_lst_scores, x_labels_scores, (15, 8)  )
plt.suptitle('SOUTHERN STATES ACT PARTICPATION AND SCORES', fontweight = 'bold', fontsize = 16)
plt.subplots_adjust(top=0.9);

# %% [markdown]
# From the above histrogram, it is evident that the participation rate is high and the students fared lower in scores. this is mentioned eariler in the heatmap which we mentioned the negatively correlation between the 2 variables. this observation backups our anaylsis that having a higher particpation rate, the scores will be lower.

# %%
# Plotting SAT Participation rates and SAT total scores from 2017 to 2019

col_lst_scores = ['participation_sat_17', 'participation_sat_18', 'participation_sat_19', 
          'total_sat_17', 'total_sat_18', 'total_sat_19']
title_lst_scores = ['SAT Participation 2017', 'SAT Participation 2018', 'SAT Participation 2019',
            'SAT Scores 2017', 'SAT Scores 2018', 'SAT Scores 2019']
x_labels_scores = ['Participation Rate', 'Participation Rate', 'Participation Rate',
            'Scores', 'Scores', 'Scores']


subplot_hist(merged_act_sats_south_reg, col_lst_scores, title_lst_scores, x_labels_scores, (15, 8)  )
plt.suptitle('SOUTHERN STATES SAT PARTICPATION AND SCORES', fontweight = 'bold', fontsize = 16)
plt.subplots_adjust(top=0.9);

# %% [markdown]
# From the SAT histrogram, we can see that the median is slighty higer with lesser participation rate. we can also see that for year 2019, the scores fared lower whilst the participation rate median increased.

# %% [markdown]
# #### 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels

# %%
# call the columns using loc and assign to variable
act_sat_bxplt = merged_act_sats_south_reg.loc[:,['participation_act_17', 'participation_act_18', 
                                                 'participation_act_19', 'participation_sat_17', 
                                                 'participation_sat_18', 'participation_sat_19' ]]

#rename columns to display in y axis boxplot                 
act_sat_bxplt = act_sat_bxplt.rename(columns={'participation_act_17' : 'ACT 2017',                                         
                                                          'participation_act_18' : 'ACT 2018',
                                                          'participation_act_19' : 'ACT 2019',
                                                          'participation_sat_17' : 'SAT 2017',
                                                          'participation_sat_18' : 'SAT 2018',
                                                          'participation_sat_19' : 'SAT 2019'})


plt.figure(figsize=(10,6))
plt.xlabel('\nParticipation Rates')
plt.ylabel('SAT or ACT Tests (Year)\n')
plt.title('Participation Rates of ACT vs SAT from 2017 to 2019\n', fontsize = 16)
sns.boxplot(data=act_sat_bxplt,orient='h');

# %% [markdown]
# * Looking at the overview data of ACT and SAT participation rate, ACT fared better then SAT. more students in the south region are taking up ACT. this is largely due to the reason that more states in the south requires students to sit for the ACT in order to graduate. We alsco can observe that the mean of ACT 19 has drasticaly dropped.
# * Take note that in 2019, SAT participation rate and the mean value is also gaining up the table.

# %% [markdown]
# #### 4. Plot and interpret scatter plots to view relationships between features.

# %%
# plot scatter plot for ACT participation and scores

plt.style.use('seaborn') # use seaborn style


fig, ax = plt.subplots(3, figsize=(10, 10)) #set figure size and set 3 rows for subplot
ax[0].scatter(x = merged_act_sats_south_reg['participation_act_17'], y = merged_act_sats_south_reg['composite_act_17'])
ax[0].set_xlabel('Participation Rate') # set x lable
ax[0].set_ylabel('Scores') # set y lable
ax[0].set_title('ACT 2017')  # set title of subplot 

ax[1].scatter(x = merged_act_sats_south_reg['participation_act_18'], y = merged_act_sats_south_reg['composite_act_18'])
ax[1].set_xlabel('Participation Rate')
ax[1].set_ylabel('Scores')
ax[1].set_title('ACT 2018')

ax[2].scatter(x = merged_act_sats_south_reg['participation_act_19'], y = merged_act_sats_south_reg['composite_act_19'])
ax[2].set_xlabel('Participation Rate')
ax[2].set_ylabel('Scores')
ax[2].set_title('ACT 2019')

plt.suptitle('ACT Participation Rates vs Scores 2017 to 2019', fontweight = 'bold', fontsize = 14) # set main title for plot
plt.tight_layout(pad = 2); # give spacing between subplots

# %% [markdown]
# * From the above scatter plots, they clearly displayed the negative corrrelation relationship between participation rate and test results. for the 3 years test, higher rates of participation correspond with lower scores by state. we also can see that states with lower participation rates, scored significantly higher.
# * this may be the willingness and determination of the students who were given a choice to take the ACT test and fared better then the students in states that are required to take the ACT test.
# * or the popluation data gathered bias by state participation

# %%
# plot scatter plot for SAT participation and scores

plt.style.use('seaborn') # use seaborn style


fig, ax = plt.subplots(3, figsize=(10, 10)) #set figure size and set 3 rows for subplot
ax[0].scatter(x = merged_act_sats_south_reg['participation_sat_17'], y = merged_act_sats_south_reg['total_sat_17'])
ax[0].set_xlabel('Participation Rate') # set x lable
ax[0].set_ylabel('Scores') # set y lable
ax[0].set_title('SAT 2017')  # set title of subplot 

ax[1].scatter(x = merged_act_sats_south_reg['participation_sat_18'], y = merged_act_sats_south_reg['total_sat_18'])
ax[1].set_xlabel('Participation Rate')
ax[1].set_ylabel('Scores')
ax[1].set_title('SAT 2018')

ax[2].scatter(x = merged_act_sats_south_reg['participation_sat_19'], y = merged_act_sats_south_reg['total_sat_19'])
ax[2].set_xlabel('Participation Rate')
ax[2].set_ylabel('Scores')
ax[2].set_title('SAT 2019')

plt.suptitle('SAT Participation Rates vs Scores 2017 to 2019', fontweight = 'bold', fontsize = 14) # set main title for plot
plt.tight_layout(pad = 2); # give spacing between subplots

# %% [markdown]
# * Similarily to the ACT scatter plot observation and findings, lower participation rates in states resulted in better faring students in scores.
# * it is also worth to note that states with options to opt for the SAT scored fairly higher as compared to ACT.

# %%
# plot ACt participation rate from 2017 to 2019 using distplot
plt.figure(figsize = (5,5))
sns.distplot(merged_act_sats_south_reg['participation_act_17'], color ='blue',  label = 'ACT 2017')
sns.distplot(merged_act_sats_south_reg['participation_act_18'], color ='red', label = 'ACT 2018')
sns.distplot(merged_act_sats_south_reg['participation_act_19'], color ='lightgreen',label = 'ACT 2019')

plt.legend()
plt.xlabel('')
plt.title('ACT participation from 2017 to 2019\n', fontsize = 18, fontweight = 'bold');
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# * it may seem that from our previous observations, ACT participation rates fare better but from the distplot above, we can observe that from 2017 to 2019, states are decreasing in participations.

# %%
# plot SAT participation rate from 2017 to 2019 using distplot
plt.figure(figsize = (5,5))
sns.distplot(merged_act_sats_south_reg['participation_sat_17'], color ='blue',  label = 'SAT 2017')
sns.distplot(merged_act_sats_south_reg['participation_sat_18'], color ='red', label = 'SAT 2018')
sns.distplot(merged_act_sats_south_reg['participation_sat_19'], color ='lightgreen',label = 'SAT 2019')

plt.legend()
plt.xlabel('')
plt.title('SAT participation from 2017 to 2019\n', fontsize = 18, fontweight = 'bold');
# Out:
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# * we can observe that SAT participation is already gaining traction from 2018 to 2019. hence particpation rates for SATs are increasing.

# %%
# plot the ACT participation rates form 2017 to 2019

# set width of bars
barwidth = 0.25

# set heights of bars
bar1 = merged_act_sats_south_reg['participation_act_17']
bar2 = merged_act_sats_south_reg['participation_act_18']
bar3 = merged_act_sats_south_reg['participation_act_19']
states = list(merged_act_sats_south_reg['state'])

# Set position of bar on X axis
r1 = np.arange(len(bar1))
r2 = [x + barwidth for x in r1]
r3 = [x + barwidth for x in r2]

# Make the plot
plt.figure(figsize = (10,6))
plt.bar(r1, bar1, width = barwidth, edgecolor  ='white', label ='2017', color = 'lightblue')
plt.bar(r2, bar2, width = barwidth, edgecolor  ='white', label ='2018')
plt.bar(r3, bar3, width = barwidth, edgecolor  ='white', label ='2019', color = 'purple')

# Add xticks on the middle of the group bars
plt.xlabel('States', fontweight='bold')
plt.ylabel('Participation Rate', fontweight='bold')
plt.xticks([r + barwidth for r in range(len(states))], states, rotation = 60)


# Create legend & Show graphic
plt.title('ACT Participant Rates from 2017 to 2019\n', fontweight = 'bold', size = 20)
plt.legend(title = 'Legend')
plt.show()

# %%
# plot the SAT participation rates form 2017 to 2019

# set width of bars
barwidth = 0.25

# set heights of bars
bar1 = merged_act_sats_south_reg['participation_sat_17']
bar2 = merged_act_sats_south_reg['participation_sat_18']
bar3 = merged_act_sats_south_reg['participation_sat_19']
states = list(merged_act_sats_south_reg['state'])

# Set position of bar on X axis
r1 = np.arange(len(bar1))
r2 = [x + barwidth for x in r1]
r3 = [x + barwidth for x in r2]

# Make the plot
plt.figure(figsize = (10,6))
plt.bar(r1, bar1, width = barwidth, edgecolor  ='white', label ='2017', color = 'lightblue')
plt.bar(r2, bar2, width = barwidth, edgecolor  ='white', label ='2018')
plt.bar(r3, bar3, width = barwidth, edgecolor  ='white', label ='2019', color = 'purple')

# Add xticks on the middle of the group bars
plt.xlabel('States', fontweight='bold')
plt.ylabel('Participation Rate', fontweight='bold')
plt.xticks([r + barwidth for r in range(len(states))], states, rotation = 60)

# Create legend & Show graphic
plt.title('SAT Participant Rates from 2017 to 2019\n', fontweight = 'bold', size = 20)
plt.legend(title = 'Legend')
plt.show()

# %% [markdown]
# * from the visulization of the barplots above, states vs participation over the 3 years, we can see there are significant shifts in participation rates from ACT to SAT for west virginia (state test requirement policy) and for florida, this may be due to programs derived from the colleage board i.e SAT school day which helped to drive up the rates.
# * whilst consistent full participation rates are evident in delware, alabama, arkansas, kentucky, louisiana, mississippi, north carolina and oklahoma because of state policy testing driven.

# %%
#plot overall scores for both ACT and SAT for 2016 - 2019
x = ['2017', '2018', '2019']
y = round(merged_act_sats_south_reg[['composite_act_17', 'composite_act_18', 'composite_act_19'] ].mean(),2)
y1 = round(merged_act_sats_south_reg[['total_sat_17', 'total_sat_18', 'total_sat_19'] ].mean(),2)

plt.figure(figsize =(12,4))

plt.subplot(121) #subplot 1
plt.plot(x, y, color = 'r', marker ='o')

plt.xlabel('Year', fontweight = 'bold')
plt.ylabel('Scores', fontweight = 'bold')
plt.title('ACT Scores', fontweight = 'bold', size = 16)
plt.ylim(20,22)

for i, v in enumerate(y): #annotate value in plot
    plt.annotate(str(v), xy=(i,v), xytext=(-7,7), textcoords='offset points')


plt.subplot(122) #subplot 2
plt.plot(x,y1, color = 'g', marker ='o')
plt.title('SAT Scores', fontweight = 'bold', size = 16)
plt.xlabel('Year', fontweight = 'bold')
plt.ylabel('Scores', fontweight = 'bold')
plt.ylim(1000,1200)

for i, v in enumerate(y1): #annotate value in plot
    plt.annotate(str(v), xy=(i,v), xytext=(-7,7), textcoords='offset points')

# %% [markdown]
# * it is observed that overall SAT average scores are in the decline. while ACT Scores are hovering within its range

# %%
#plot overall scores for both ACT and SAT for 2016 - 2019
x = ['2017', '2018', '2019']
y = round(merged_act_sats_south_reg[['participation_act_17', 'participation_act_18', 'participation_act_19'] ].mean(),2)
y1 = round(merged_act_sats_south_reg[['participation_sat_17', 'participation_sat_18', 'participation_sat_19'] ].mean(),2)

plt.figure(figsize =(12,4))

plt.subplot(121) #subplot 1
plt.plot(x, y, color = 'r', marker ='o')

plt.xlabel('Year', fontweight = 'bold')
plt.ylabel('Rate', fontweight = 'bold')
plt.title('ACT Participation\n', fontweight = 'bold', size = 16)


for i, v in enumerate(y): #annotate value in plot
    plt.annotate(str(v), xy=(i,v), xytext=(-7,7), textcoords='offset points')


plt.subplot(122) #subplot 2
plt.plot(x,y1, color = 'g', marker ='o')
plt.title('SAT Participation\n', fontweight = 'bold', size = 16)
plt.xlabel('Year', fontweight = 'bold')
plt.ylabel('Rate', fontweight = 'bold')


for i, v in enumerate(y1): #annotate value in plot
    plt.annotate(str(v), xy=(i,v), xytext=(-7,7), textcoords='offset points')

# %% [markdown]
# * from the above, plots. it is evident that participation rates for ACT is on the decline while SAT participation rate is on the raise

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Overall, the participation rate for the southern states are healthy in the region with all the states in the south does not within the region of less than 50 % participation for both tests. high participation rates are state policy driven as we can see in delware, alabama, arkansas, kentucky, louisiana, mississippi, north carolina and oklahoma participation rates data.
#
# It is observed that Virginia was the lowest participation rate for SAT and ACT in 2019, thus we will be recommending Virginia to the College board fund investment to boost their SAT scores.
#
# It also noteable that SAT school day is evidently fruitful in assisting states to increase their participation as seen in Florida. This programme can be adopted for Viriginia and or any other states with non testing policy driven states with low participation rates.
# *  whereby the easing of locating a testing center where student can take the test in their schools, giving the studet more comfort and familiar with the surrounding of environment and people.
# *  School test day, the test to be conducted on a week day in school as part of the school's schedule. students need not take time off to participate in the the test or disruption of work schedule or family time.
# *  builds confidence for students through offering of practice plans for tests
# *  financial support for low income students for application of colleges
#
# There are some states that still offers end of course tests as part of their graduation requirement. We will recommend states to drop these tests as a requirement for students to graduate high school, as this would reduce the load of tests that students would need to take and elimate different standards among all the states. we will propose for national test taking for either SAT or the ACT. schools could provide pre-assessment of their students to which test that the students are more incline to perform better and recommend students to take up either the ACT or SAT test. with this recommendation, states are better able to judge their performance and participation across all states.
#
# Lastly, it is observed that SAT test scores are on the decline, thus it is also recommended that the colleage board look into how we can improve the student scores. More participation dosen't mean it is good. we will also want students to score better through better preparation and guidance. We will also need to take note of selection bias of data comparisons. there should be two groups of comparison whereby the 1st group will be comparisons between voluntary taking of test versus results and the 2nd group to be among state policy test driven  results. this recommendation would avoid selection bias and provide a more accurate result.
